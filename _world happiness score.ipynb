# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Using pandas representing data in DataFrame format
df=pd.read_csv("happiness_score_dataset.csv") 
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
#Checking if there are any null values in our data frame
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
# Visualizing Null Values
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
# We can see that we have 9 float columns, 1 integer value column and 2 object datatype columns

# %%
df['Happiness Score'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 153    3.465
# 154    3.340
# 155    3.006
# 156    2.905
# 157    2.839
# Name: Happiness Score, Length: 158, dtype: float64>

# %%
# Checking duplicate values
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 153    False
# 154    False
# 155    False
# 156    False
# 157    False
# Length: 158, dtype: bool

# %%
df.drop_duplicates()
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
# Statistical summary

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [raw]
# This gives us the statistical summary of our Dataset. We can note following points from here
# 1) mean is slightly greater than median in happines score,standard error,trust and generosity which means our data is slightly skeweed to the right.
# 2)mean is slightly lesser than median in happiness rank, economy,family health and freedom which indicates these data are skewed to the left.
# 3) there is huge difference in 75% and max of happiness rank and slight difference in 75% and max of coloumns respectively which indicates that outliers are present in dataset

# %%
#CHecking the correlation
corre=df.corr()
corre
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
# Data analysis of correlation via Visualisation usng seaborn and matplotlib
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(), linewidths = 0.1, fmt = ".1g", linecolor= "black" ,annot=True,cmap="Blues_r")
plt.yticks(rotation=0)
plt.show()

# %%
# Since our model can understand only integer values so we apply label encoder to convert string cloumns into interger values
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
list1=['Country','Region']
for val in list1:
    df[val]=le.fit_transform(df[val].astype(str))
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153      118       8             154            3.465         0.03464
# 154       13       8             155            3.340         0.03656
# 155      136       4             156            3.006         0.05015
# 156       21       8             157            2.905         0.08658
# 157      141       8             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
corre=df.corr()
corre
# Out:
#                                 Country    Region  Happiness Rank  \
# Country                        1.000000  0.005092       -0.098538
# Region                         0.005092  1.000000        0.213773
# Happiness Rank                -0.098538  0.213773        1.000000
# Happiness Score                0.083380 -0.176791       -0.992105
# Standard Error                 0.033879 -0.022600        0.158516
# Economy (GDP per Capita)       0.037808 -0.260139       -0.785267
# Family                         0.159416 -0.168533       -0.733644
# Health (Life Expectancy)       0.037829 -0.357508       -0.735613
# Freedom                        0.085684  0.092567       -0.556886
# Trust (Government Corruption)  0.088155  0.165040       -0.372315
# Generosity                     0.118085  0.273557       -0.160142
# Dystopia Residual             -0.019778 -0.057276       -0.521999
#
#                                Happiness Score  Standard Error  \
# ...

# %% [markdown]
# # Data Visualisation

# %% [raw]
# univariate analysis

# %%
# visualising the counts of all coulums
for i in df.columns:
    print(df[i].value_counts())
    sns.countplot(df[i])
    plt.subplots()
# Out:
# 135    1
# 10     1
# 51     1
# 77     1
# 57     1
#       ..
# 70     1
# 125    1
# 81     1
# 101    1
# 141    1
# Name: Country, Length: 158, dtype: int64
# 8    40
# 1    29
# 3    22
# 9    21
# 4    20
# 6     9
# 7     7
# 2     6
# 5     2
# 0     2
# Name: Region, dtype: int64
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: Happiness Rank, Length: 157, dtype: int64
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# 2.839    1
# Name: Happiness Score, Length: 157, dtype: int64
# 0.03780    2
# 0.03751    2
# 0.04394    2
# 0.05051    2
# 0.04934    2
#           ..
# 0.04114    1
# 0.04251    1
# 0.03843    1
# 0.05371    1
# 0.06727    1
# Name: Standard Error, Length: 153, dtype: int64
# 1.39651    1
# 0.39753    1
# 1.15406    1
# 1.02564    1
# 1.12094    1
#           ..
# 1.12254    1
# 1.18498    1
# ...

# %%
# Now Lets Check the distruibution of our columns

# %%
plt.figure(figsize=(20,8),facecolor="White")
plotnumber=1
for i in df.columns:
    if plotnumber<=12:
        ax=plt.subplot(3,6,plotnumber)
        sns.distplot(df[i],color='m')
        plt.xlabel(i,fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [raw]
# Bivariate analysis

# %%
sns.scatterplot(x='Standard Error',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Happiness Score',y='Economy (GDP per Capita)',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Economy (GDP per Capita)'>

# %%
sns.scatterplot(x='Family',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Dystopia Residual',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Happiness Score'>

# %%
plt.title('Comparision between Dystopia Residual and Happiness Score')
sns.stripplot(x='Dystopia Residual',y='Happiness Score',data=df,palette='bright')
plt.show()

# %%
sns.pairplot(df,palette='Dark2')
plt.show()

# %%
plt.boxplot(df['Standard Error'])
plt.show()

# %%
plt.boxplot(df['Family'])
plt.show()

# %%
plt.boxplot(df['Happiness Rank'])
plt.show()

# %%
df.corr()['Happiness Score'].sort_values()
# Out:
# Happiness Rank                  -0.992105
# Standard Error                  -0.177254
# Region                          -0.176791
# Country                          0.083380
# Generosity                       0.180319
# Trust (Government Corruption)    0.395199
# Dystopia Residual                0.530474
# Freedom                          0.568211
# Health (Life Expectancy)         0.724200
# Family                           0.740605
# Economy (GDP per Capita)         0.780966
# Happiness Score                  1.000000
# Name: Happiness Score, dtype: float64

# %%
#Checking the skewness in our Data
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
#Using seaborn, checking if our data is Normal distribution or not,or there are any skewness in data via Visualisation
sns.distplot(df["Standard Error"])
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Density'>

# %%
sns.distplot(df['Economy (GDP per Capita)'])
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
sns.distplot(df['Family'])
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %%
sns.distplot(df['Health (Life Expectancy)'])
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
sns.distplot(df['Freedom'])
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Density'>

# %%
sns.distplot(df['Trust (Government Corruption)'])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.distplot(df['Generosity'])
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %%
sns.distplot(df['Dystopia Residual'])
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %%
# Statistically analysing and removing outliers
from scipy.stats import zscore

# %%
zscore(df)
# Out:
#       Country    Region  Happiness Rank  Happiness Score  Standard Error  \
# 0    1.238770  1.300256       -1.721000         1.937360       -0.805926
# 1   -0.449465  1.300256       -1.699075         1.914581        0.055889
# 2   -0.909893  1.300256       -1.677149         1.884792       -0.854487
# 3    0.581016  1.300256       -1.655224         1.880411       -0.531526
# 4   -1.194920 -0.040302       -1.633299         1.797179       -0.722845
# ..        ...       ...             ...              ...             ...
# 153  0.866043  0.965117        1.633576        -1.674055       -0.774917
# 154 -1.436096  0.965117        1.655501        -1.783571       -0.662582
# 155  1.260695 -0.375441        1.677427        -2.076199        0.132534
# 156 -1.260695  0.965117        1.699352        -2.164688        2.263962
# 157  1.370321  0.965117        1.721277        -2.222513        1.134182
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# ...

# %%
#Using absolute function for conb=verting all negative values into positive
z=np.abs(zscore(df))
z
# Out:
#       Country    Region  Happiness Rank  Happiness Score  Standard Error  \
# 0    1.238770  1.300256        1.721000         1.937360        0.805926
# 1    0.449465  1.300256        1.699075         1.914581        0.055889
# 2    0.909893  1.300256        1.677149         1.884792        0.854487
# 3    0.581016  1.300256        1.655224         1.880411        0.531526
# 4    1.194920  0.040302        1.633299         1.797179        0.722845
# ..        ...       ...             ...              ...             ...
# 153  0.866043  0.965117        1.633576         1.674055        0.774917
# 154  1.436096  0.965117        1.655501         1.783571        0.662582
# 155  1.260695  0.375441        1.677427         2.076199        0.132534
# 156  1.260695  0.965117        1.699352         2.164688        2.263962
# 157  1.370321  0.965117        1.721277         2.222513        1.134182
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# ...

# %%
# Finding all locations where zscore has value greater than 3 to find outliers
np.where(z>3)
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64),
#  array([ 9,  4,  4,  4, 10,  6,  9, 11,  6], dtype=int64))

# %%
# Removing outliers
df_new=df[(z<3).all(axis=1)]

# %%
df_new.shape
# Out:
# (149, 12)

# %%
df.shape
# Out:
# (158, 12)

# %%
# Checking Data Loss Percentage
DLP=(158-149)/158*100
print('Data Loss Precentage is ',DLP)
# Out:
# Data Loss Precentage is  5.69620253164557

# %%
# New df is our x Data which has no outliers
x=df_new.iloc[:,[0,1,2,4,5,6,7,8,9,10,11]]
x
# Out:
#      Country  Region  Happiness Rank  Standard Error  \
# 0        135       9               1         0.03411
# 1         58       9               2         0.04884
# 2         37       9               3         0.03328
# 3        105       9               4         0.03880
# 4         24       5               5         0.03553
# ..       ...     ...             ...             ...
# 150       66       8             151         0.05141
# 151       20       8             152         0.04324
# 152        0       7             153         0.03084
# 154       13       8             155         0.03656
# 156       21       8             157         0.08658
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
# This is our targrt or label
y=df_new.iloc[:,3]
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 150    3.655
# 151    3.587
# 152    3.575
# 154    3.340
# 156    2.905
# Name: Happiness Score, Length: 149, dtype: float64

# %%
y.shape
# Out:
# (149,)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=pd.DataFrame(sc.fit_transform(x),columns=x.columns)
x
# Out:
#       Country    Region  Happiness Rank  Standard Error  \
# 0    1.268260  1.296837       -1.713905       -0.866786
# 1   -0.417415  1.296837       -1.691535        0.185669
# 2   -0.877145  1.296837       -1.669166       -0.926089
# 3    0.611504  1.296837       -1.646796       -0.531687
# 4   -1.161739 -0.026647       -1.624427       -0.765327
# ..        ...       ...             ...             ...
# 144 -0.242280  0.965966        1.641542        0.369294
# 145 -1.249307  0.965966        1.663911       -0.214450
# 146 -1.687145  0.635095        1.686281       -1.100427
# 147 -1.402550  0.965966        1.731020       -0.691734
# 148 -1.227415  0.965966        1.775759        2.882182
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.381916  1.357879                  1.235390  1.583704
# 1                    1.138324  1.567882                  1.261541  1.338953
# ...

# %%
# Checking for Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def cal_vif(x):
    vif=pd.DataFrame()
    vif['Features']=x.columns
    vif['VIF Value']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
    return vif

# %%
cal_vif(x)
# Out:
#                          Features  VIF Value
# 0                         Country   1.067384
# 1                          Region   1.482686
# 2                  Happiness Rank  86.816086
# 3                  Standard Error   1.216881
# 4        Economy (GDP per Capita)  14.167853
# 5                          Family   6.488548
# 6        Health (Life Expectancy)   9.076391
# 7                         Freedom   3.644844
# 8   Trust (Government Corruption)   1.996101
# 9                      Generosity   2.254469
# 10              Dystopia Residual  20.169500

# %% [raw]
# There is a Huge Multicollinearity in colum Happiness rank,Economy and Dystopia Residual. so lets Drop Happines Rank and again check multicollinearity

# %%
x.drop(['Happiness Rank'],axis=1,inplace=True)

# %%
cal_vif(x)
# Out:
#                         Features  VIF Value
# 0                        Country   1.062465
# 1                         Region   1.420903
# 2                 Standard Error   1.187950
# 3       Economy (GDP per Capita)   4.301663
# 4                         Family   2.030036
# 5       Health (Life Expectancy)   3.982297
# 6                        Freedom   1.870343
# 7  Trust (Government Corruption)   1.499097
# 8                     Generosity   1.477571
# 9              Dystopia Residual   1.036890

# %%
# Now There is no multicollinearity present in our DataSet

# %% [markdown]
# # Model Building

# %%
# From now on we will be working on our model building, here we are first taking linear Regression since we are dealing with cotinious data and checking r2 score as well.  
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
lm=LinearRegression()

# %%
# Selecting best Random State for training and testng
for i in range(0,100):
    xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=i)
    lm.fit(xtrain,ytrain)
    predlm=lm.predict(xtest)
    lmacc=r2_score(ytest,predlm)
    print('At Random state ',i,' Accuracy is ',lmacc*100)
    print("\n")
# Out:
# At Random state  0  Accuracy is  99.99999138569436
#
#
# At Random state  1  Accuracy is  99.99998774383933
#
#
# At Random state  2  Accuracy is  99.99999368978636
#
#
# At Random state  3  Accuracy is  99.999991783255
#
#
# At Random state  4  Accuracy is  99.99999405077229
#
#
# At Random state  5  Accuracy is  99.99999325471532
#
#
# At Random state  6  Accuracy is  99.99999153815524
#
#
# At Random state  7  Accuracy is  99.99998420035831
#
#
# At Random state  8  Accuracy is  99.99999596899123
#
#
# At Random state  9  Accuracy is  99.99999271786454
#
#
# At Random state  10  Accuracy is  99.99999309855507
#
#
# At Random state  11  Accuracy is  99.99999362086936
#
#
# At Random state  12  Accuracy is  99.99999530460477
#
#
# At Random state  13  Accuracy is  99.99999349760444
#
#
# At Random state  14  Accuracy is  99.99999274254114
#
#
# At Random state  15  Accuracy is  99.99998980634567
#
#
# At Random state  16  Accuracy is  99.99999277424733
#
#
# ...

# %%
# Since 37 is our best random state, for final modelling at random state 60
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=60)

# %%
print('Accuracy is ',r2_score(ytest,predlm)*100)
# Out:
# Accuracy is  99.99999336497444

# %%
print('MSE is ',mean_squared_error(ytest,predlm))
print('MAE is ',mean_absolute_error(ytest,predlm))
# Out:
# MSE is  7.515825647696196e-08
# MAE is  0.00024065880430802858

# %%
# Selecting the best CV value (Cross validation helps us to find underfitting and overfitting of model)
from sklearn.model_selection import cross_val_score
for i in range(2,10):
    cv_score=cross_val_score(lm,x,y,cv=i)*100
    cv_mean=cv_score.mean()
    print(f'At cv value {i} the cross val score is {cv_mean} and  accuracy is ',r2_score(ytest,predlm)*100)
    print('\n')
# Out:
# At cv value 2 the cross val score is 99.99996577888072 and  accuracy is  99.99999336497444
#
#
# At cv value 3 the cross val score is 99.99994569337686 and  accuracy is  99.99999336497444
#
#
# At cv value 4 the cross val score is 99.99986774348555 and  accuracy is  99.99999336497444
#
#
# At cv value 5 the cross val score is 99.99981755824281 and  accuracy is  99.99999336497444
#
#
# At cv value 6 the cross val score is 99.99971630162723 and  accuracy is  99.99999336497444
#
#
# At cv value 7 the cross val score is 99.99954663191538 and  accuracy is  99.99999336497444
#
#
# At cv value 8 the cross val score is 99.99949302150837 and  accuracy is  99.99999336497444
#
#
# At cv value 9 the cross val score is 99.99936488905247 and  accuracy is  99.99999336497444

# %%
# Since 2 is the best CV
cv_score1=cross_val_score(lm,x,y,cv=2)*100
cv_mean1=cv_score1.mean()

# %%
cvlm=cross_val_score(lm,x,y,cv=2)
cvlm_mean=cvlm.mean()
print('At CV 2 cross val score is ',cvlm_mean*100,' with accuracy ',lmacc*100)
# Out:
# At CV 2 cross val score is  99.99996577888072  with accuracy  99.99999336497444

# %%
# PLotting the Linear Regression graph between predicted and actual values and Visualize if our data lies on the best fit line
plt.figure(figsize=(8,6))
plt.scatter(x=ytest,y=predlm,color='r')
plt.plot(ytest,ytest,color='b')
plt.xlabel('Actual score',fontsize=14)
plt.ylabel('Predicted score',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %%
# Now using HyperParameter tuning for finding best parameters for our new Lasso algorithm
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso

# %%
lss=Lasso()

# %%
parameters={'alpha':[.0001,.001,.01,1,10],'random_state':list(range(0,10))}
GV=GridSearchCV(lss,parameters)
GV.fit(xtrain,ytrain)
print(GV.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
# Checking the performance of our model with Lasso algorithm.
lss=Lasso(alpha=0.0001,random_state=0)
lss.fit(xtrain,ytrain)
predlss=lss.predict(xtest)
lssacc=r2_score(ytest,predlss)

# %%
print('Accuracy of Lasso is ',lssacc*100)
print('MSE is ',mean_squared_error(ytest,predlss))
print('MAE is ',mean_absolute_error(ytest,predlss))
# Out:
# Accuracy of Lasso is  99.99999152367984
# MSE is  9.601552221156424e-08
# MAE is  0.0002719133622228161

# %%
# Checking the R2 Score of lasso alorithm
lsacc=r2_score(ytest,lspred)*100
lsacc
# Out:
# 99.99958646874369

# %%
# Checking the Cross Validation Score
for i in range(2,10):
    cvls=cross_val_score(lss,x,y,cv=i)
    cvls_mean=cvls.mean()
    print('At cross val score ',i,' the cv in ',cvls_mean*100,' with acc ',lsacc)
# Out:
# At cross val score  2  the cv in  99.99947945444694  with acc  99.99958646874369
# At cross val score  3  the cv in  99.99976124466855  with acc  99.99958646874369
# At cross val score  4  the cv in  99.99968253348442  with acc  99.99958646874369
# At cross val score  5  the cv in  99.99960986361138  with acc  99.99958646874369
# At cross val score  6  the cv in  99.99948295556041  with acc  99.99958646874369
# At cross val score  7  the cv in  99.99935348974134  with acc  99.99958646874369
# At cross val score  8  the cv in  99.99925046033475  with acc  99.99958646874369
# At cross val score  9  the cv in  99.99910506627539  with acc  99.99958646874369

# %%
#Best CV at 2

# %%
cvls=cross_val_score(lss,x,y,cv=2)
cvls_mean=cvls.mean()
print('At cross val score ',i,' the cv in ',cvls_mean*100,' with acc ',lsacc)
# Out:
# At cross val score  9  the cv in  99.99947945444694  with acc  99.99958646874369

# %%
print('At cross val score 2 the cv in ',cvls_mean*100,' with acc ',lsacc)
# Out:
# At cross val score 2 the cv in  99.99947945444694  with acc  99.99958646874369

# %%
from sklearn.linear_model import Ridge

# %%
parameters={'alpha':[.0001,.001,.01,1,10],'random_state':list(range(0,10))}
rd=Ridge()
GV2=GridSearchCV(rd,parameters)
GV2.fit(xtrain,ytrain)
print(GV2.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
rd=Ridge(alpha=0.0001,random_state=0)
rd.fit(xtrain,ytrain)
predrd=rd.predict(xtest)
rdacc=r2_score(ytest,predrd)

# %%
rdacc*100
# Out:
# 99.99999336633977

# %%
print('Accuracy of Ridge is ',rdacc*100)
print('MSE is ',mean_squared_error(ytest,predrd))
print('MAE is ',mean_absolute_error(ytest,predrd))
# Out:
# Accuracy of Ridge is  99.99999336633977
# MSE is  7.514279067235137e-08
# MAE is  0.00024066679998154447

# %%
cvrd=cross_val_score(rd,x,y,cv=2)
cvrd_mean=cvrd.mean()
print('At cross val score 2 the cv in ',cvrd_mean*100,' with acc ',rdacc*100)
# Out:
# At cross val score 2 the cv in  99.99996544715509  with acc  99.99999336633977

# %%
from sklearn.linear_model import ElasticNet

# %%
en=ElasticNet()
parameters={'alpha':[.0001,.001,.01,1,10],'random_state':list(range(0,10))}
GV3=GridSearchCV(en,parameters)
GV3.fit(xtrain,ytrain)
print(GV3.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
en=ElasticNet(alpha=0.0001,random_state=0)
en.fit(xtrain,ytrain)
preden=en.predict(xtest)
enacc=r2_score(ytest,preden)

# %%
print('Accuracy of elastic net is ',enacc*100)
print('MSE is ',mean_squared_error(ytest,preden))
print('MAE is ',mean_absolute_error(ytest,preden))
# Out:
# Accuracy of elastic net is  99.99999346881225
# MSE is  7.398203358433027e-08
# MAE is  0.00024188618010210957

# %%
cven=cross_val_score(en,x,y,cv=2)
cven_mean=cven.mean()
print('At cross val score 2 the cv in ',cven_mean*100,' with acc ',enacc*100)
# Out:
# At cross val score 2 the cv in  99.99971162621215  with acc  99.99999346881225

# %%
# selecting the best parameters for our RandomForestRegressors using GridSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
parameters={'criterion':['squared_error','absolute_error','poisson'],'max_features':['auto','sqrt','log']}
rf=RandomForestRegressor()
GVV=GridSearchCV(rf,parameters)
GVV.fit(xtrain,ytrain)
print(GVV.best_params_)
# Out:
# {'criterion': 'absolute_error', 'max_features': 'auto'}

# %%
# Checking the performance of model using RandomForest Algorithm
rf=RandomForestRegressor(criterion='absolute_error',max_features='auto')
rf.fit(xtrain,ytrain)
predrf=rf.predict(xtest)
rfacc=r2_score(ytest,predrf)

# %%
print('Accuracy score of Random Forest Regressor is ',rfacc*100)
print('MSE is ',mean_squared_error(ytest,predrf))
print('MAE is ',mean_absolute_error(ytest,predrf))
# Out:
# Accuracy score of Random Forest Regressor is  85.78366754808106
# MSE is  0.1610355153266668
# MAE is  0.32360933333333347

# %%
cvrf=cross_val_score(rf,x,y,cv=2)
cvrf_mean=cvrf.mean()
print('At cross val score 2 the cv in ',cvrf_mean*100,' with acc ',rfacc*100)
# Out:
# At cross val score 2 the cv in  -458.50253058651447  with acc  85.78366754808106

# %%
# Based on checking the cross val score and r2_score ridge is our best model

# %%
# Saving The Model using pickle library
import pickle
filename='hss.pkl'
pickle.dump(rd,open(filename,'wb'))

# %%
output=pickle.load(open('hss.pkl','rb'))
result=output.score(xtest,ytest)
print(result*100)
# Out:
# 99.99999336633977

# %%
model=pd.DataFrame([output.predict(xtest)[:],(predrd)[:]],index=['original','predicted'])
model.transpose()
# Out:
#     original  predicted
# 0   3.819241   3.819241
# 1   7.286192   7.286192
# 2   5.267940   5.267940
# 3   4.419315   4.419315
# 4   7.427022   7.427022
# 5   5.007086   5.007086
# 6   5.192304   5.192304
# 7   4.677373   4.677373
# 8   6.786223   6.786223
# 9   5.398790   5.398790
# 10  4.350098   4.350098
# 11  5.057309   5.057309
# 12  4.252013   4.252013
# 13  4.884529   4.884529
# 14  4.296765   4.296765
# 15  6.946131   6.946131
# 16  7.284225   7.284225
# 17  5.360159   5.360159
# 18  5.128742   5.128742
# 19  4.685599   4.685599
# 20  5.101471   5.101471
# 21  5.855242   5.855242
# 22  5.959738   5.959738
# 23  5.140470   5.140470
# 24  4.512316   4.512316
# 25  7.378102   7.378102
# 26  5.987095   5.987095
# 27  3.574703   3.574703
# 28  5.770379   5.770379
# 29  4.714798   4.714798

# %%
# We can see our model is performing extremely well.
# thank you
